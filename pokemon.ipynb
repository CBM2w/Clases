# %%
class Nodo:
    def __init__(self, dato):
        # "dato" puede ser de cualquier tipo, incluso un objeto si se sobrescriben los operadores de comparación
        self.dato = dato
        self.izquierda = None
        self.derecha = None


class Arbol:
    # Funciones privadas
    def __init__(self, dato):
        self.raiz = Nodo(dato)

    def __agregar_recursivo(self, nodo, dato):
        if dato < nodo.dato:
            if nodo.izquierda is None:
                nodo.izquierda = Nodo(dato)
            else:
                self.__agregar_recursivo(nodo.izquierda, dato)
        else:
            if nodo.derecha is None:
                nodo.derecha = Nodo(dato)
            else:
                self.__agregar_recursivo(nodo.derecha, dato)

    def __inorden_recursivo(self, nodo):
        if nodo is not None:
            self.__inorden_recursivo(nodo.izquierda)
            print(nodo.dato, end=", ")
            self.__inorden_recursivo(nodo.derecha)

    def __preorden_recursivo(self, nodo):
        if nodo is not None:
            print(nodo.dato, end=", ")
            self.__preorden_recursivo(nodo.izquierda)
            self.__preorden_recursivo(nodo.derecha)

    def __postorden_recursivo(self, nodo):
        if nodo is not None:
            self.__postorden_recursivo(nodo.izquierda)
            self.__postorden_recursivo(nodo.derecha)
            print(nodo.dato, end=", ")

    def __buscar(self, nodo, busqueda):
        if nodo is None:
            return None
        if nodo.dato == busqueda:
            return nodo
        if busqueda < nodo.dato:
            return self.__buscar(nodo.izquierda, busqueda)
        else:
            return self.__buscar(nodo.derecha, busqueda)

    # Funciones públicas

    def agregar(self, dato):
        self.__agregar_recursivo(self.raiz, dato)

    def inorden(self):
        print("Imprimiendo árbol inorden: ")
        self.__inorden_recursivo(self.raiz)
        print("")

    def preorden(self):
        print("Imprimiendo árbol preorden: ")
        self.__preorden_recursivo(self.raiz)
        print("")

    def postorden(self):
        print("Imprimiendo árbol postorden: ")
        self.__postorden_recursivo(self.raiz)
        print("")

    def buscar(self, busqueda):
        return self.__buscar(self.raiz, busqueda)

# %%
import pandas as pd

pokemon = pd.read_csv('C:/Users/Carla/Documents/CLASES PROGRAMACIÓN/Clases-1/pokemon (1).csv')
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon = pokemon.dropna()

# %%
arbol_num = Arbol(pokemon.iloc[0]['#'])

for i in pokemon['#'][1:]:
    arbol_num.agregar(i)

arbol_num.preorden()

# %%
arbol_nombres = Arbol(pokemon.iloc[0]['Name'])

for i in pokemon['Name'][1:]:
    arbol_nombres.agregar(i)

arbol_nombres.preorden()

# %%
arbol_tipo = Arbol(pokemon.iloc[0]['Type 1'])

for i in pokemon['Type 1'][1:]:
    arbol_tipo.agregar(i)

arbol_tipo.preorden()

# %%
def buscar_nombre():
    nombre = input('Nombre: ')
    lista_nombres = []

    for i in pokemon['Name']:
        if nombre in i:
            lista_nombres.append(i)
    
    return lista_nombres

#print(buscar_nombre())

nombres = buscar_nombre()

# %%
def datosPokemon():
    nombre = buscar_nombre()
    datos = []
    for n in nombre:
        for p in range(len(pokemon['Name'])):
            if n == pokemon.iloc[p]["Name"]:
                datos.append(pokemon.iloc[p])
                
    return datos

print(datosPokemon())
# Out:
# [#                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object, #                     9
# Name          Blastoise
# Type 1            Water
# Type 2              NaN
# Total               530
# HP                   79
# Attack               83
# Defense             100
# Sp. Atk              85
# Sp. Def             105
# Speed                78
# Generation            1
# Legendary         False
# Name: 11, dtype: object, #                                   9
# Name          BlastoiseMega Blastoise
# Type 1                          Water
# Type 2                            NaN
# Total                             630
# HP                                 79
# ...

# %%
def buscar_num():
    numero = int(input('Número: '))
    
    for p in pokemon['#']:
        if numero == p:
            print(pokemon.loc[p-1])

buscar_num()
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
def buscar_tipo():
    tipo = input('Tipo: ')

    for t in range(len(pokemon['Type 1'])):
        if tipo == pokemon.iloc[t]['Type 1']:
            print(pokemon.iloc[t]['Name'])

buscar_tipo()

# %%
pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
def debilidad():
    datos = datosPokemon()
    debilidad = []

    for e in datos:
        debilidad.append(e['Type 2'])         
    return debilidad
    
print(debilidad())
# Out:
# Bulbasaur
# Butterfree
# Beedrill
# BeedrillMega Beedrill
# Bellsprout
# Blaziken
# BlazikenMega Blaziken
# Beautifly
# Breloom
# Barboach
# Baltoy
# Beldum
# Bibarel
# Budew
# Bastiodon
# Bronzor
# Bronzong
# Bisharp
# Braviary
# KyuremBlack Kyurem
# AegislashBlade Forme
# Binacle
# Barbaracle
# ['Poison', 'Flying', 'Poison', 'Poison', 'Poison', 'Fighting', 'Fighting', 'Flying', 'Fighting', 'Ground', 'Psychic', 'Psychic', 'Water', 'Poison', 'Steel', 'Psychic', 'Psychic', 'Steel', 'Flying', 'Ice', 'Ghost', 'Water', 'Water']

# %%
def rivales():
    datos = datosPokemon()
    tipo = datos[0]['Type 1']
    debiles = []

    for i in range(len(pokemon)):
        if pokemon.iloc[i]['Type 2'] == tipo:
            debiles.append(pokemon.iloc[i]['Name'])

    return debiles


print(rivales())
# Out:
# ['Paras', 'Parasect', 'Celebi', 'Lotad', 'Lombre', 'Ludicolo', 'Lileep', 'Cradily', 'WormadamPlant Cloak', 'RotomMow Rotom', 'Sewaddle', 'Swadloon', 'Leavanny', 'Deerling', 'Sawsbuck', 'Phantump', 'Trevenant', 'PumpkabooAverage Size', 'PumpkabooSmall Size', 'PumpkabooLarge Size', 'PumpkabooSuper Size', 'GourgeistAverage Size', 'GourgeistSmall Size', 'GourgeistLarge Size', 'GourgeistSuper Size']

# %%
def debiles_tipo():
    tipo = input('Tipo: ')
    debiles = []

    for i in range(len(pokemon)):
        if pokemon.iloc[i]['Type 2'] == tipo:
            if pokemon.iloc[i]['Type 1'] not in debiles:
                debiles.append(pokemon.iloc[i]['Type 1'])

    return debiles

print(debiles_tipo())
# Out:
# ['Bug', 'Psychic', 'Water', 'Rock', 'Electric', 'Normal', 'Ghost']
